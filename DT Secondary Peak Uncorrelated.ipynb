# %%
import uproot
import matplotlib.pyplot as plt
import awkward as ak

sameSignFile=uproot.open('highHcal_data_tagAligned (1).root')
sameSignFile
# Out:
# <ReadOnlyDirectory '/' at 0x026aa22830d0>

# %%
sameSignFile.keys()
# Out:
# ['demo;1',
#  'demo/allEvents;1',
#  'demo/allEvents/genEventCount;1',
#  'demo/allEvents/genEventCount_EnBin;1',
#  'demo/allEvents/sigVariables;1',
#  'demo/allEvents/eventCount;1',
#  'demo/allEvents/eventCount_PUup;1',
#  'demo/allEvents/eventCount_PUdown;1',
#  'demo/allEvents/eventCount_IDup;1',
#  'demo/allEvents/eventCount_IDdown;1',
#  'demo/allEvents/eventCount_ISOup;1',
#  'demo/allEvents/eventCount_ISOdown;1',
#  'demo/allEvents/eventCount_Trigup;1',
#  'demo/allEvents/eventCount_Trigdown;1',
#  'demo/allEvents/eventCount_EnBin;1',
#  'demo/allEvents/dbremWeight;1',
#  'demo/allEvents/MuRocWeight;1',
#  'demo/allEvents/IDSF;1',
#  'demo/allEvents/IDSFup;1',
#  'demo/allEvents/IDSFdown;1',
#  'demo/allEvents/ISOSF;1',
#  'demo/allEvents/ISOSFup;1',
#  'demo/allEvents/ISOSFdown;1',
#  'demo/allEvents/TrigSF;1',
#  'demo/allEvents/TrigSFup;1',
#  'demo/allEvents/TrigSFdown;1',
#  'demo/allEvents/cutProgress;1',
#  'demo/allEvents/signalCategory;1',
#  'demo/allEvents/DiMuonInvariantMass;1',
#  'demo/allEvents/TaggingMuonEta;1',
#  'demo/allEvents/TaggingMuonPt;1',
#  'demo/allEvents/NumberOfSelectedMuons;1',
#  'demo/allEvents/NumberOfPairedProbes;1',
#  'demo/allEvents/NeighborHCALHits;1',
#  'demo/allEvents/NeighborHCALEnergy;1',
#  'demo/allEvents/NeighborHEHitsByDepth;1',
#  'demo/allEvents/ConeHits;1',
#  'demo/allEvents/ConeEnergy;1',
#  'demo/allEvents/ConeEnergy_PUup;1',
#  'demo/allEvents/ConeEnergy_PUdown;1',
#  'demo/allEvents/ConeEnergy_IDup;1',
#  'demo/allEvents/ConeEnergy_IDdown;1',
#  'demo/allEvents/ConeEnergy_ISOup;1',
#  'demo/allEvents/ConeEnergy_ISOdown;1',
#  'demo/allEvents/ConeEnergy_Trigup;1',
#  'demo/allEvents/ConeEnergy_Trigdown;1',
#  'demo/allEvents/ConeEnergy_EnBin;1',
#  'demo/allEvents/NMatchNHitConeEnergy;1',
#  'demo/allEvents/NMatchNHitLocation;1',
#  'demo/allEvents/ProbeTrackPt;1',
#  'demo/allEvents/ProbeTrackP;1',
#  'demo/allEvents/ProbeTrackEta;1',
#  'demo/allEvents/ProbeTrackPtEta;1',
#  'demo/allEvents/ProbeTrackEtaPhi;1',
#  'demo/allEvents/DarkBremLocation;1',
#  'demo/allEvents/DeflectingAngle;1',
#  'demo/allEvents/MuInitialE;1',
#  'demo/allEvents/MuInitialE_noWeight;1',
#  'demo/allEvents/MuInitialEt;1',
#  'demo/allEvents/MuFinalE;1',
#  'demo/allEvents/DarkBremScalingDistance;1',
#  'demo/allEvents/ProbeEcalIsolation;1',
#  'demo/allEvents/ProbeEcalIsolation0p2;1',
#  'demo/allEvents/ProbeEcalIsolation0p1;1',
#  'demo/allEvents/ProbeEcalIsolation0p05;1',
#  'demo/allEvents/MotherTrackdE;1',
#  'demo/allEvents/MotherTrackdR;1',
#  'demo/allEvents/FailLocation;1',
#  'demo/allEvents/FractionalELost;1',
#  'demo/allEvents/HitsOverThresh;1',
#  'demo/allEvents/BremDepth;1',
#  'demo/allEvents/dRtoNearestCSC;1',
#  'demo/allEvents/dRtoNearestCSC_Station0;1',
#  'demo/allEvents/dRtoNearestDT_Station0;1',
#  'demo/allEvents/dRtoNearestCSC_Station0missing;1',
#  'demo/allEvents/dRtoNearestCSC_Station0good;1',
#  'demo/allEvents/dRtoNearestCSC_Station0goodonly;1',
#  'demo/allEvents/dRtoNearestCSC_Station1;1',
#  'demo/allEvents/dRtoNearestDT_Station1;1',
#  'demo/allEvents/dRtoNearestCSC_Station1missing;1',
#  'demo/allEvents/dRtoNearestCSC_Station1good;1',
#  'demo/allEvents/dRtoNearestCSC_Station1goodonly;1',
#  'demo/allEvents/dRtoNearestCSC_Station2;1',
#  'demo/allEvents/dRtoNearestDT_Station2;1',
#  'demo/allEvents/dRtoNearestCSC_Station2missing;1',
#  'demo/allEvents/dRtoNearestCSC_Station2good;1',
#  'demo/allEvents/dRtoNearestCSC_Station2goodonly;1',
#  'demo/allEvents/dRtoNearestCSC_Station3;1',
#  'demo/allEvents/dRtoNearestDT_Station3;1',
#  'demo/allEvents/dRtoNearestCSC_Station3missing;1',
#  'demo/allEvents/dRtoNearestCSC_Station3good;1',
#  'demo/allEvents/dRtoNearestCSC_Station3goodonly;1',
#  'demo/allEvents/dRtoNearestSimCSC;1',
#  'demo/allEvents/minSimCSCEloss;1',
#  'demo/allEvents/nSimCSCHits;1',
#  'demo/allEvents/nRecoCSCHits;1',
#  'demo/allEvents/dRtoNearestCSCRecHit;1',
#  'demo/allEvents/MuonMotherdE;1',
#  'demo/allEvents/MuonMotherdR;1',
#  'demo/allEvents/minGenMuDr;1',
#  'demo/allEvents/minGenMuDE;1',
#  'demo/allEvents/CSCChiSquared;1',
#  'demo/allEvents/CSCDeflection;1',
#  'demo/allEvents/StandaloneMuonE;1',
#  'demo/allEvents/GlobaldMuonE;1',
#  'demo/allEvents/StandaloneMuondEoverE;1',
#  'demo/allEvents/StandaloneMuondEoverE_PUup;1',
#  'demo/allEvents/StandaloneMuondEoverE_PUdown;1',
#  'demo/allEvents/StandaloneMuondEoverE_IDup;1',
#  'demo/allEvents/StandaloneMuondEoverE_IDdown;1',
#  'demo/allEvents/StandaloneMuondEoverE_ISOup;1',
#  'demo/allEvents/StandaloneMuondEoverE_ISOdown;1',
#  'demo/allEvents/StandaloneMuondEoverE_Trigup;1',
#  'demo/allEvents/StandaloneMuondEoverE_Trigdown;1',
#  'demo/allEvents/StandaloneMuondEoverE_EnBin;1',
#  'demo/allEvents/MatchedLocation;1',
#  'demo/allEvents/AllClosestApproach;1',
#  'demo/allEvents/EventWeights;1',
#  'demo/allEvents/Dark Brem R;1',
#  'demo/allEvents/HEHitsByDepth;1',
#  'demo/allEvents/DrtoNearestStandalone;1',
#  'demo/allEvents/ProbePFJetDr;1',
#  'demo/allEvents/ProbePFJetE;1',
#  'demo/allEvents/ProbePFJetMaxE;1',
#  'demo/allEvents/Njets;1',
#  'demo/allEvents/nLooseBTagJets;1',
#  'demo/allEvents/nMedBTagJets;1',
#  'demo/allEvents/nTightBTagjets;1',
#  'demo/allEvents/MinCaloJetDr;1',
#  'demo/allEvents/CaloJetPt;1',
#  'demo/allEvents/CaloJetPt_CaloConeEnergy;1',
#  'demo/allEvents/CaloJetEcalE;1',
#  'demo/allEvents/CaloJetHcalE;1',
#  'demo/allEvents/CaloJetTotalE;1',
#  'demo/allEvents/CaloConeEnergy;1',
#  'demo/allEvents/hcalIso0p3;1',
#  'demo/allEvents/hcalIso0p4;1',
#  'demo/allEvents/CaloConeHits;1',
#  'demo/allEvents/NHECellsFound;1',
#  'demo/allEvents/NeighborHECellsFound;1',
#  'demo/allEvents/HEEStandDEOverE;1',
#  'demo/allEvents/CSCdEtadPhi;1',
#  'demo/allEvents/CSCdEtadPhiPosQ;1',
#  'demo/allEvents/CSCdEtadPhiNegQ;1',
#  'demo/allEvents/CSCdPhi;1',
#  'demo/allEvents/CSCdPhiPosQ;1',
#  'demo/allEvents/CSCdPhiNegQ;1',
#  'demo/allEvents/standalonedPhi_hcalE;1',
#  'demo/allEvents/standalonedPhi_hcalE_lowStaDEoverE;1',
#  'demo/allEvents/StandalonedPhi;1',
#  'demo/allEvents/StandalonedPhiPosQ;1',
#  'demo/allEvents/StandalonedPhiPosQstaDEoverE;1',
#  'demo/allEvents/StandalonedPhiNegQ;1',
#  'demo/allEvents/StandalonedPhiNegQstaDEoverE;1',
#  'demo/allEvents/StandalonedEtadPhi;1',
#  'demo/allEvents/StandalonedEtadPhiPosQ;1',
#  'demo/allEvents/StandalonedEtadPhiNegQ;1',
#  'demo/allEvents/BigEtaCellCenterDistance;1',
#  'demo/allEvents/SmallEtaCellCenterDistance;1',
#  'demo/allEvents/CSCMinImpact;1',
#  'demo/allEvents/PairedVtxReducedChiSq;1',
#  'demo/allEvents/TrackIsolation;1',
#  'demo/allEvents/TrackQuality;1',
#  'demo/allEvents/TrackReducedChi;1',
#  'demo/allEvents/HcalPlusEcalE;1',
#  'demo/allEvents/ProbeTrackdxy;1',
#  'demo/allEvents/ProbeTrackdsz;1',
#  'demo/allEvents/ProbeTrackDCA;1',
#  'demo/allEvents/ProbeTrackLongDCA;1',
#  'demo/allEvents/ProbeTrackDCAphi;1',
#  'demo/allEvents/nElectrons;1',
#  'demo/allEvents/nExtraElectrons;1',
#  'demo/allEvents/nExtraMuons;1',
#  'demo/allEvents/standaloneChi2;1',
#  'demo/allEvents/standaloneNHits;1',
#  'demo/allEvents/standaloneTDCA;1',
#  'demo/allEvents/standaloneLongDCA;1',
#  'demo/allEvents/standalonechidEoverE;1',
#  'demo/allEvents/GenStandaloneMuondEoverE;1',
#  'demo/allEvents/DisGenStandaloneMuondEoverE;1',
#  'demo/allEvents/PileupWeights;1',
#  'demo/allEvents/NPUMean;1',
#  'demo/allEvents/energyBinSF;1',
#  'demo/allEvents/energyBin;1',
#  'demo/allEvents/totalMET;1',
#  'demo/allEvents/muMetMT;1',
#  'demo/allEvents/muAndProbeMetMT;1',
#  'demo/allEvents/depthsFound;1',
#  'demo/genAccepted;1',
#  'demo/genAccepted/genEventCount;1',
#  'demo/genAccepted/genEventCount_EnBin;1',
#  'demo/genAccepted/sigVariables;1',
#  'demo/genAccepted/eventCount;1',
#  'demo/genAccepted/eventCount_PUup;1',
#  'demo/genAccepted/eventCount_PUdown;1',
#  'demo/genAccepted/eventCount_IDup;1',
#  'demo/genAccepted/eventCount_IDdown;1',
#  'demo/genAccepted/eventCount_ISOup;1',
#  'demo/genAccepted/eventCount_ISOdown;1',
#  'demo/genAccepted/eventCount_Trigup;1',
#  'demo/genAccepted/eventCount_Trigdown;1',
#  'demo/genAccepted/eventCount_EnBin;1',
#  'demo/genAccepted/dbremWeight;1',
#  'demo/genAccepted/MuRocWeight;1',
#  'demo/genAccepted/IDSF;1',
#  'demo/genAccepted/IDSFup;1',
#  'demo/genAccepted/IDSFdown;1',
#  'demo/genAccepted/ISOSF;1',
#  'demo/genAccepted/ISOSFup;1',
#  'demo/genAccepted/ISOSFdown;1',
#  'demo/genAccepted/TrigSF;1',
#  'demo/genAccepted/TrigSFup;1',
#  'demo/genAccepted/TrigSFdown;1',
#  'demo/genAccepted/cutProgress;1',
#  'demo/genAccepted/signalCategory;1',
#  'demo/genAccepted/DiMuonInvariantMass;1',
#  'demo/genAccepted/TaggingMuonEta;1',
#  'demo/genAccepted/TaggingMuonPt;1',
#  'demo/genAccepted/NumberOfSelectedMuons;1',
#  'demo/genAccepted/NumberOfPairedProbes;1',
#  'demo/genAccepted/NeighborHCALHits;1',
#  'demo/genAccepted/NeighborHCALEnergy;1',
#  'demo/genAccepted/NeighborHEHitsByDepth;1',
#  'demo/genAccepted/ConeHits;1',
#  'demo/genAccepted/ConeEnergy;1',
#  'demo/genAccepted/ConeEnergy_PUup;1',
#  'demo/genAccepted/ConeEnergy_PUdown;1',
#  'demo/genAccepted/ConeEnergy_IDup;1',
#  'demo/genAccepted/ConeEnergy_IDdown;1',
#  'demo/genAccepted/ConeEnergy_ISOup;1',
#  'demo/genAccepted/ConeEnergy_ISOdown;1',
#  'demo/genAccepted/ConeEnergy_Trigup;1',
#  'demo/genAccepted/ConeEnergy_Trigdown;1',
#  'demo/genAccepted/ConeEnergy_EnBin;1',
#  'demo/genAccepted/NMatchNHitConeEnergy;1',
#  'demo/genAccepted/NMatchNHitLocation;1',
#  'demo/genAccepted/ProbeTrackPt;1',
#  'demo/genAccepted/ProbeTrackP;1',
#  'demo/genAccepted/ProbeTrackEta;1',
#  'demo/genAccepted/ProbeTrackPtEta;1',
#  'demo/genAccepted/ProbeTrackEtaPhi;1',
#  'demo/genAccepted/DarkBremLocation;1',
#  'demo/genAccepted/DeflectingAngle;1',
#  'demo/genAccepted/MuInitialE;1',
#  'demo/genAccepted/MuInitialE_noWeight;1',
#  'demo/genAccepted/MuInitialEt;1',
#  'demo/genAccepted/MuFinalE;1',
#  'demo/genAccepted/DarkBremScalingDistance;1',
#  'demo/genAccepted/ProbeEcalIsolation;1',
#  'demo/genAccepted/ProbeEcalIsolation0p2;1',
#  'demo/genAccepted/ProbeEcalIsolation0p1;1',
#  'demo/genAccepted/ProbeEcalIsolation0p05;1',
#  'demo/genAccepted/MotherTrackdE;1',
#  'demo/genAccepted/MotherTrackdR;1',
#  'demo/genAccepted/FailLocation;1',
#  'demo/genAccepted/FractionalELost;1',
#  'demo/genAccepted/HitsOverThresh;1',
#  'demo/genAccepted/BremDepth;1',
#  'demo/genAccepted/dRtoNearestCSC;1',
#  'demo/genAccepted/dRtoNearestCSC_Station0;1',
#  'demo/genAccepted/dRtoNearestDT_Station0;1',
#  'demo/genAccepted/dRtoNearestCSC_Station0missing;1',
#  'demo/genAccepted/dRtoNearestCSC_Station0good;1',
#  'demo/genAccepted/dRtoNearestCSC_Station0goodonly;1',
#  'demo/genAccepted/dRtoNearestCSC_Station1;1',
#  'demo/genAccepted/dRtoNearestDT_Station1;1',
#  'demo/genAccepted/dRtoNearestCSC_Station1missing;1',
#  'demo/genAccepted/dRtoNearestCSC_Station1good;1',
#  'demo/genAccepted/dRtoNearestCSC_Station1goodonly;1',
#  'demo/genAccepted/dRtoNearestCSC_Station2;1',
#  'demo/genAccepted/dRtoNearestDT_Station2;1',
#  'demo/genAccepted/dRtoNearestCSC_Station2missing;1',
#  'demo/genAccepted/dRtoNearestCSC_Station2good;1',
#  'demo/genAccepted/dRtoNearestCSC_Station2goodonly;1',
#  'demo/genAccepted/dRtoNearestCSC_Station3;1',
#  'demo/genAccepted/dRtoNearestDT_Station3;1',
#  'demo/genAccepted/dRtoNearestCSC_Station3missing;1',
#  'demo/genAccepted/dRtoNearestCSC_Station3good;1',
#  'demo/genAccepted/dRtoNearestCSC_Station3goodonly;1',
#  'demo/genAccepted/dRtoNearestSimCSC;1',
#  'demo/genAccepted/minSimCSCEloss;1',
#  'demo/genAccepted/nSimCSCHits;1',
#  'demo/genAccepted/nRecoCSCHits;1',
#  'demo/genAccepted/dRtoNearestCSCRecHit;1',
#  'demo/genAccepted/MuonMotherdE;1',
#  'demo/genAccepted/MuonMotherdR;1',
#  'demo/genAccepted/minGenMuDr;1',
#  'demo/genAccepted/minGenMuDE;1',
#  'demo/genAccepted/CSCChiSquared;1',
#  'demo/genAccepted/CSCDeflection;1',
#  'demo/genAccepted/StandaloneMuonE;1',
#  'demo/genAccepted/GlobaldMuonE;1',
#  'demo/genAccepted/StandaloneMuondEoverE;1',
#  'demo/genAccepted/StandaloneMuondEoverE_PUup;1',
#  'demo/genAccepted/StandaloneMuondEoverE_PUdown;1',
#  'demo/genAccepted/StandaloneMuondEoverE_IDup;1',
#  'demo/genAccepted/StandaloneMuondEoverE_IDdown;1',
#  'demo/genAccepted/StandaloneMuondEoverE_ISOup;1',
#  'demo/genAccepted/StandaloneMuondEoverE_ISOdown;1',
#  'demo/genAccepted/StandaloneMuondEoverE_Trigup;1',
#  'demo/genAccepted/StandaloneMuondEoverE_Trigdown;1',
#  'demo/genAccepted/StandaloneMuondEoverE_EnBin;1',
#  'demo/genAccepted/MatchedLocation;1',
#  'demo/genAccepted/AllClosestApproach;1',
#  'demo/genAccepted/EventWeights;1',
#  'demo/genAccepted/Dark Brem R;1',
#  'demo/genAccepted/HEHitsByDepth;1',
#  'demo/genAccepted/DrtoNearestStandalone;1',
#  'demo/genAccepted/ProbePFJetDr;1',
#  'demo/genAccepted/ProbePFJetE;1',
#  'demo/genAccepted/ProbePFJetMaxE;1',
#  'demo/genAccepted/Njets;1',
#  'demo/genAccepted/nLooseBTagJets;1',
#  'demo/genAccepted/nMedBTagJets;1',
#  'demo/genAccepted/nTightBTagjets;1',
#  'demo/genAccepted/MinCaloJetDr;1',
#  'demo/genAccepted/CaloJetPt;1',
#  'demo/genAccepted/CaloJetPt_CaloConeEnergy;1',
#  'demo/genAccepted/CaloJetEcalE;1',
#  'demo/genAccepted/CaloJetHcalE;1',
#  'demo/genAccepted/CaloJetTotalE;1',
#  'demo/genAccepted/CaloConeEnergy;1',
#  'demo/genAccepted/hcalIso0p3;1',
#  'demo/genAccepted/hcalIso0p4;1',
#  'demo/genAccepted/CaloConeHits;1',
#  'demo/genAccepted/NHECellsFound;1',
#  'demo/genAccepted/NeighborHECellsFound;1',
#  'demo/genAccepted/HEEStandDEOverE;1',
#  'demo/genAccepted/CSCdEtadPhi;1',
#  'demo/genAccepted/CSCdEtadPhiPosQ;1',
#  'demo/genAccepted/CSCdEtadPhiNegQ;1',
#  'demo/genAccepted/CSCdPhi;1',
#  'demo/genAccepted/CSCdPhiPosQ;1',
#  'demo/genAccepted/CSCdPhiNegQ;1',
#  'demo/genAccepted/standalonedPhi_hcalE;1',
#  'demo/genAccepted/standalonedPhi_hcalE_lowStaDEoverE;1',
#  'demo/genAccepted/StandalonedPhi;1',
#  'demo/genAccepted/StandalonedPhiPosQ;1',
#  'demo/genAccepted/StandalonedPhiPosQstaDEoverE;1',
#  'demo/genAccepted/StandalonedPhiNegQ;1',
#  'demo/genAccepted/StandalonedPhiNegQstaDEoverE;1',
#  'demo/genAccepted/StandalonedEtadPhi;1',
#  'demo/genAccepted/StandalonedEtadPhiPosQ;1',
#  'demo/genAccepted/StandalonedEtadPhiNegQ;1',
#  'demo/genAccepted/BigEtaCellCenterDistance;1',
#  'demo/genAccepted/SmallEtaCellCenterDistance;1',
#  'demo/genAccepted/CSCMinImpact;1',
#  'demo/genAccepted/PairedVtxReducedChiSq;1',
#  'demo/genAccepted/TrackIsolation;1',
#  'demo/genAccepted/TrackQuality;1',
#  'demo/genAccepted/TrackReducedChi;1',
#  'demo/genAccepted/HcalPlusEcalE;1',
#  'demo/genAccepted/ProbeTrackdxy;1',
#  'demo/genAccepted/ProbeTrackdsz;1',
#  'demo/genAccepted/ProbeTrackDCA;1',
#  'demo/genAccepted/ProbeTrackLongDCA;1',
#  'demo/genAccepted/ProbeTrackDCAphi;1',
#  'demo/genAccepted/nElectrons;1',
#  'demo/genAccepted/nExtraElectrons;1',
#  'demo/genAccepted/nExtraMuons;1',
#  'demo/genAccepted/standaloneChi2;1',
#  'demo/genAccepted/standaloneNHits;1',
#  'demo/genAccepted/standaloneTDCA;1',
#  'demo/genAccepted/standaloneLongDCA;1',
#  'demo/genAccepted/standalonechidEoverE;1',
#  'demo/genAccepted/GenStandaloneMuondEoverE;1',
#  'demo/genAccepted/DisGenStandaloneMuondEoverE;1',
#  'demo/genAccepted/PileupWeights;1',
#  'demo/genAccepted/NPUMean;1',
#  'demo/genAccepted/energyBinSF;1',
#  'demo/genAccepted/energyBin;1',
#  'demo/genAccepted/totalMET;1',
#  'demo/genAccepted/muMetMT;1',
#  'demo/genAccepted/muAndProbeMetMT;1',
#  'demo/genAccepted/depthsFound;1',
#  'demo/genInfo;1',
#  'demo/genInfo/genEventCount;1',
#  'demo/genInfo/genEventCount_EnBin;1',
#  'demo/genInfo/sigVariables;1',
#  'demo/genInfo/eventCount;1',
#  'demo/genInfo/eventCount_PUup;1',
#  'demo/genInfo/eventCount_PUdown;1',
#  'demo/genInfo/eventCount_IDup;1',
#  'demo/genInfo/eventCount_IDdown;1',
#  'demo/genInfo/eventCount_ISOup;1',
#  'demo/genInfo/eventCount_ISOdown;1',
#  'demo/genInfo/eventCount_Trigup;1',
#  'demo/genInfo/eventCount_Trigdown;1',
#  'demo/genInfo/eventCount_EnBin;1',
#  'demo/genInfo/dbremWeight;1',
#  'demo/genInfo/MuRocWeight;1',
#  'demo/genInfo/IDSF;1',
#  'demo/genInfo/IDSFup;1',
#  'demo/genInfo/IDSFdown;1',
#  'demo/genInfo/ISOSF;1',
#  'demo/genInfo/ISOSFup;1',
#  'demo/genInfo/ISOSFdown;1',
#  'demo/genInfo/TrigSF;1',
#  'demo/genInfo/TrigSFup;1',
#  'demo/genInfo/TrigSFdown;1',
#  'demo/genInfo/cutProgress;1',
#  'demo/genInfo/signalCategory;1',
#  'demo/genInfo/DiMuonInvariantMass;1',
#  'demo/genInfo/TaggingMuonEta;1',
#  'demo/genInfo/TaggingMuonPt;1',
#  'demo/genInfo/NumberOfSelectedMuons;1',
#  'demo/genInfo/NumberOfPairedProbes;1',
#  'demo/genInfo/NeighborHCALHits;1',
#  'demo/genInfo/NeighborHCALEnergy;1',
#  'demo/genInfo/NeighborHEHitsByDepth;1',
#  'demo/genInfo/ConeHits;1',
#  'demo/genInfo/ConeEnergy;1',
#  'demo/genInfo/ConeEnergy_PUup;1',
#  'demo/genInfo/ConeEnergy_PUdown;1',
#  'demo/genInfo/ConeEnergy_IDup;1',
#  'demo/genInfo/ConeEnergy_IDdown;1',
#  'demo/genInfo/ConeEnergy_ISOup;1',
#  'demo/genInfo/ConeEnergy_ISOdown;1',
#  'demo/genInfo/ConeEnergy_Trigup;1',
#  'demo/genInfo/ConeEnergy_Trigdown;1',
#  'demo/genInfo/ConeEnergy_EnBin;1',
#  'demo/genInfo/NMatchNHitConeEnergy;1',
#  'demo/genInfo/NMatchNHitLocation;1',
#  'demo/genInfo/ProbeTrackPt;1',
#  'demo/genInfo/ProbeTrackP;1',
#  'demo/genInfo/ProbeTrackEta;1',
#  'demo/genInfo/ProbeTrackPtEta;1',
#  'demo/genInfo/ProbeTrackEtaPhi;1',
#  'demo/genInfo/DarkBremLocation;1',
#  'demo/genInfo/DeflectingAngle;1',
#  'demo/genInfo/MuInitialE;1',
#  'demo/genInfo/MuInitialE_noWeight;1',
#  'demo/genInfo/MuInitialEt;1',
#  'demo/genInfo/MuFinalE;1',
#  'demo/genInfo/DarkBremScalingDistance;1',
#  'demo/genInfo/ProbeEcalIsolation;1',
#  'demo/genInfo/ProbeEcalIsolation0p2;1',
#  'demo/genInfo/ProbeEcalIsolation0p1;1',
#  'demo/genInfo/ProbeEcalIsolation0p05;1',
#  'demo/genInfo/MotherTrackdE;1',
#  'demo/genInfo/MotherTrackdR;1',
#  'demo/genInfo/FailLocation;1',
#  'demo/genInfo/FractionalELost;1',
#  'demo/genInfo/HitsOverThresh;1',
#  'demo/genInfo/BremDepth;1',
#  'demo/genInfo/dRtoNearestCSC;1',
#  'demo/genInfo/dRtoNearestCSC_Station0;1',
#  'demo/genInfo/dRtoNearestDT_Station0;1',
#  'demo/genInfo/dRtoNearestCSC_Station0missing;1',
#  'demo/genInfo/dRtoNearestCSC_Station0good;1',
#  'demo/genInfo/dRtoNearestCSC_Station0goodonly;1',
#  'demo/genInfo/dRtoNearestCSC_Station1;1',
#  'demo/genInfo/dRtoNearestDT_Station1;1',
#  'demo/genInfo/dRtoNearestCSC_Station1missing;1',
#  'demo/genInfo/dRtoNearestCSC_Station1good;1',
#  'demo/genInfo/dRtoNearestCSC_Station1goodonly;1',
#  'demo/genInfo/dRtoNearestCSC_Station2;1',
#  'demo/genInfo/dRtoNearestDT_Station2;1',
#  'demo/genInfo/dRtoNearestCSC_Station2missing;1',
#  'demo/genInfo/dRtoNearestCSC_Station2good;1',
#  'demo/genInfo/dRtoNearestCSC_Station2goodonly;1',
#  'demo/genInfo/dRtoNearestCSC_Station3;1',
#  'demo/genInfo/dRtoNearestDT_Station3;1',
#  'demo/genInfo/dRtoNearestCSC_Station3missing;1',
#  'demo/genInfo/dRtoNearestCSC_Station3good;1',
#  'demo/genInfo/dRtoNearestCSC_Station3goodonly;1',
#  'demo/genInfo/dRtoNearestSimCSC;1',
#  'demo/genInfo/minSimCSCEloss;1',
#  'demo/genInfo/nSimCSCHits;1',
#  'demo/genInfo/nRecoCSCHits;1',
#  'demo/genInfo/dRtoNearestCSCRecHit;1',
#  'demo/genInfo/MuonMotherdE;1',
#  'demo/genInfo/MuonMotherdR;1',
#  'demo/genInfo/minGenMuDr;1',
#  'demo/genInfo/minGenMuDE;1',
#  'demo/genInfo/CSCChiSquared;1',
#  'demo/genInfo/CSCDeflection;1',
#  'demo/genInfo/StandaloneMuonE;1',
#  'demo/genInfo/GlobaldMuonE;1',
#  'demo/genInfo/StandaloneMuondEoverE;1',
#  'demo/genInfo/StandaloneMuondEoverE_PUup;1',
#  'demo/genInfo/StandaloneMuondEoverE_PUdown;1',
#  'demo/genInfo/StandaloneMuondEoverE_IDup;1',
#  'demo/genInfo/StandaloneMuondEoverE_IDdown;1',
#  'demo/genInfo/StandaloneMuondEoverE_ISOup;1',
#  'demo/genInfo/StandaloneMuondEoverE_ISOdown;1',
#  'demo/genInfo/StandaloneMuondEoverE_Trigup;1',
#  'demo/genInfo/StandaloneMuondEoverE_Trigdown;1',
#  'demo/genInfo/StandaloneMuondEoverE_EnBin;1',
#  'demo/genInfo/MatchedLocation;1',
#  'demo/genInfo/AllClosestApproach;1',
#  'demo/genInfo/EventWeights;1',
#  'demo/genInfo/Dark Brem R;1',
#  'demo/genInfo/HEHitsByDepth;1',
#  'demo/genInfo/DrtoNearestStandalone;1',
#  'demo/genInfo/ProbePFJetDr;1',
#  'demo/genInfo/ProbePFJetE;1',
#  'demo/genInfo/ProbePFJetMaxE;1',
#  'demo/genInfo/Njets;1',
#  'demo/genInfo/nLooseBTagJets;1',
#  'demo/genInfo/nMedBTagJets;1',
#  'demo/genInfo/nTightBTagjets;1',
#  'demo/genInfo/MinCaloJetDr;1',
#  'demo/genInfo/CaloJetPt;1',
#  'demo/genInfo/CaloJetPt_CaloConeEnergy;1',
#  'demo/genInfo/CaloJetEcalE;1',
#  'demo/genInfo/CaloJetHcalE;1',
#  'demo/genInfo/CaloJetTotalE;1',
#  'demo/genInfo/CaloConeEnergy;1',
#  'demo/genInfo/hcalIso0p3;1',
#  'demo/genInfo/hcalIso0p4;1',
#  'demo/genInfo/CaloConeHits;1',
#  'demo/genInfo/NHECellsFound;1',
#  'demo/genInfo/NeighborHECellsFound;1',
#  'demo/genInfo/HEEStandDEOverE;1',
#  'demo/genInfo/CSCdEtadPhi;1',
#  'demo/genInfo/CSCdEtadPhiPosQ;1',
#  'demo/genInfo/CSCdEtadPhiNegQ;1',
#  'demo/genInfo/CSCdPhi;1',
#  'demo/genInfo/CSCdPhiPosQ;1',
#  'demo/genInfo/CSCdPhiNegQ;1',
#  'demo/genInfo/standalonedPhi_hcalE;1',
#  'demo/genInfo/standalonedPhi_hcalE_lowStaDEoverE;1',
#  'demo/genInfo/StandalonedPhi;1',
#  'demo/genInfo/StandalonedPhiPosQ;1',
#  'demo/genInfo/StandalonedPhiPosQstaDEoverE;1',
#  'demo/genInfo/StandalonedPhiNegQ;1',
#  'demo/genInfo/StandalonedPhiNegQstaDEoverE;1',
#  'demo/genInfo/StandalonedEtadPhi;1',
#  'demo/genInfo/StandalonedEtadPhiPosQ;1',
#  'demo/genInfo/StandalonedEtadPhiNegQ;1',
#  'demo/genInfo/BigEtaCellCenterDistance;1',
#  'demo/genInfo/SmallEtaCellCenterDistance;1',
#  'demo/genInfo/CSCMinImpact;1',
#  'demo/genInfo/PairedVtxReducedChiSq;1',
#  'demo/genInfo/TrackIsolation;1',
#  'demo/genInfo/TrackQuality;1',
#  'demo/genInfo/TrackReducedChi;1',
#  'demo/genInfo/HcalPlusEcalE;1',
#  'demo/genInfo/ProbeTrackdxy;1',
#  'demo/genInfo/ProbeTrackdsz;1',
#  'demo/genInfo/ProbeTrackDCA;1',
#  'demo/genInfo/ProbeTrackLongDCA;1',
#  'demo/genInfo/ProbeTrackDCAphi;1',
#  'demo/genInfo/nElectrons;1',
#  'demo/genInfo/nExtraElectrons;1',
#  'demo/genInfo/nExtraMuons;1',
#  'demo/genInfo/standaloneChi2;1',
#  'demo/genInfo/standaloneNHits;1',
#  'demo/genInfo/standaloneTDCA;1',
#  'demo/genInfo/standaloneLongDCA;1',
#  'demo/genInfo/standalonechidEoverE;1',
#  'demo/genInfo/GenStandaloneMuondEoverE;1',
#  'demo/genInfo/DisGenStandaloneMuondEoverE;1',
#  'demo/genInfo/PileupWeights;1',
#  'demo/genInfo/NPUMean;1',
#  'demo/genInfo/energyBinSF;1',
#  'demo/genInfo/energyBin;1',
#  'demo/genInfo/totalMET;1',
#  'demo/genInfo/muMetMT;1',
#  'demo/genInfo/muAndProbeMetMT;1',
#  'demo/genInfo/depthsFound;1',
#  'demo/preSelected;1',
#  'demo/preSelected/genEventCount;1',
#  'demo/preSelected/genEventCount_EnBin;1',
#  'demo/preSelected/sigVariables;1',
#  'demo/preSelected/eventCount;1',
#  'demo/preSelected/eventCount_PUup;1',
#  'demo/preSelected/eventCount_PUdown;1',
#  'demo/preSelected/eventCount_IDup;1',
#  'demo/preSelected/eventCount_IDdown;1',
#  'demo/preSelected/eventCount_ISOup;1',
#  'demo/preSelected/eventCount_ISOdown;1',
#  'demo/preSelected/eventCount_Trigup;1',
#  'demo/preSelected/eventCount_Trigdown;1',
#  'demo/preSelected/eventCount_EnBin;1',
#  'demo/preSelected/dbremWeight;1',
#  'demo/preSelected/MuRocWeight;1',
#  'demo/preSelected/IDSF;1',
#  'demo/preSelected/IDSFup;1',
#  'demo/preSelected/IDSFdown;1',
#  'demo/preSelected/ISOSF;1',
#  'demo/preSelected/ISOSFup;1',
#  'demo/preSelected/ISOSFdown;1',
#  'demo/preSelected/TrigSF;1',
#  'demo/preSelected/TrigSFup;1',
#  'demo/preSelected/TrigSFdown;1',
#  'demo/preSelected/cutProgress;1',
#  'demo/preSelected/signalCategory;1',
#  'demo/preSelected/DiMuonInvariantMass;1',
#  'demo/preSelected/TaggingMuonEta;1',
#  'demo/preSelected/TaggingMuonPt;1',
#  'demo/preSelected/NumberOfSelectedMuons;1',
#  'demo/preSelected/NumberOfPairedProbes;1',
#  'demo/preSelected/NeighborHCALHits;1',
#  'demo/preSelected/NeighborHCALEnergy;1',
#  'demo/preSelected/NeighborHEHitsByDepth;1',
#  'demo/preSelected/ConeHits;1',
#  'demo/preSelected/ConeEnergy;1',
#  'demo/preSelected/ConeEnergy_PUup;1',
#  'demo/preSelected/ConeEnergy_PUdown;1',
#  'demo/preSelected/ConeEnergy_IDup;1',
#  'demo/preSelected/ConeEnergy_IDdown;1',
#  'demo/preSelected/ConeEnergy_ISOup;1',
#  'demo/preSelected/ConeEnergy_ISOdown;1',
#  'demo/preSelected/ConeEnergy_Trigup;1',
#  'demo/preSelected/ConeEnergy_Trigdown;1',
#  'demo/preSelected/ConeEnergy_EnBin;1',
#  'demo/preSelected/NMatchNHitConeEnergy;1',
#  'demo/preSelected/NMatchNHitLocation;1',
#  'demo/preSelected/ProbeTrackPt;1',
#  'demo/preSelected/ProbeTrackP;1',
#  'demo/preSelected/ProbeTrackEta;1',
#  'demo/preSelected/ProbeTrackPtEta;1',
#  'demo/preSelected/ProbeTrackEtaPhi;1',
#  'demo/preSelected/DarkBremLocation;1',
#  'demo/preSelected/DeflectingAngle;1',
#  'demo/preSelected/MuInitialE;1',
#  'demo/preSelected/MuInitialE_noWeight;1',
#  'demo/preSelected/MuInitialEt;1',
#  'demo/preSelected/MuFinalE;1',
#  'demo/preSelected/DarkBremScalingDistance;1',
#  'demo/preSelected/ProbeEcalIsolation;1',
#  'demo/preSelected/ProbeEcalIsolation0p2;1',
#  'demo/preSelected/ProbeEcalIsolation0p1;1',
#  'demo/preSelected/ProbeEcalIsolation0p05;1',
#  'demo/preSelected/MotherTrackdE;1',
#  'demo/preSelected/MotherTrackdR;1',
#  'demo/preSelected/FailLocation;1',
#  'demo/preSelected/FractionalELost;1',
#  'demo/preSelected/HitsOverThresh;1',
#  'demo/preSelected/BremDepth;1',
#  'demo/preSelected/dRtoNearestCSC;1',
#  'demo/preSelected/dRtoNearestCSC_Station0;1',
#  'demo/preSelected/dRtoNearestDT_Station0;1',
#  'demo/preSelected/dRtoNearestCSC_Station0missing;1',
#  'demo/preSelected/dRtoNearestCSC_Station0good;1',
#  'demo/preSelected/dRtoNearestCSC_Station0goodonly;1',
#  'demo/preSelected/dRtoNearestCSC_Station1;1',
#  'demo/preSelected/dRtoNearestDT_Station1;1',
#  'demo/preSelected/dRtoNearestCSC_Station1missing;1',
#  'demo/preSelected/dRtoNearestCSC_Station1good;1',
#  'demo/preSelected/dRtoNearestCSC_Station1goodonly;1',
#  'demo/preSelected/dRtoNearestCSC_Station2;1',
#  'demo/preSelected/dRtoNearestDT_Station2;1',
#  'demo/preSelected/dRtoNearestCSC_Station2missing;1',
#  'demo/preSelected/dRtoNearestCSC_Station2good;1',
#  'demo/preSelected/dRtoNearestCSC_Station2goodonly;1',
#  'demo/preSelected/dRtoNearestCSC_Station3;1',
#  'demo/preSelected/dRtoNearestDT_Station3;1',
#  'demo/preSelected/dRtoNearestCSC_Station3missing;1',
#  'demo/preSelected/dRtoNearestCSC_Station3good;1',
#  'demo/preSelected/dRtoNearestCSC_Station3goodonly;1',
#  'demo/preSelected/dRtoNearestSimCSC;1',
#  'demo/preSelected/minSimCSCEloss;1',
#  'demo/preSelected/nSimCSCHits;1',
#  'demo/preSelected/nRecoCSCHits;1',
#  'demo/preSelected/dRtoNearestCSCRecHit;1',
#  'demo/preSelected/MuonMotherdE;1',
#  'demo/preSelected/MuonMotherdR;1',
#  'demo/preSelected/minGenMuDr;1',
#  'demo/preSelected/minGenMuDE;1',
#  'demo/preSelected/CSCChiSquared;1',
#  'demo/preSelected/CSCDeflection;1',
#  'demo/preSelected/StandaloneMuonE;1',
#  'demo/preSelected/GlobaldMuonE;1',
#  'demo/preSelected/StandaloneMuondEoverE;1',
#  'demo/preSelected/StandaloneMuondEoverE_PUup;1',
#  'demo/preSelected/StandaloneMuondEoverE_PUdown;1',
#  'demo/preSelected/StandaloneMuondEoverE_IDup;1',
#  'demo/preSelected/StandaloneMuondEoverE_IDdown;1',
#  'demo/preSelected/StandaloneMuondEoverE_ISOup;1',
#  'demo/preSelected/StandaloneMuondEoverE_ISOdown;1',
#  'demo/preSelected/StandaloneMuondEoverE_Trigup;1',
#  'demo/preSelected/StandaloneMuondEoverE_Trigdown;1',
#  'demo/preSelected/StandaloneMuondEoverE_EnBin;1',
#  'demo/preSelected/MatchedLocation;1',
#  'demo/preSelected/AllClosestApproach;1',
#  'demo/preSelected/EventWeights;1',
#  'demo/preSelected/Dark Brem R;1',
#  'demo/preSelected/HEHitsByDepth;1',
#  'demo/preSelected/DrtoNearestStandalone;1',
#  'demo/preSelected/ProbePFJetDr;1',
#  'demo/preSelected/ProbePFJetE;1',
#  'demo/preSelected/ProbePFJetMaxE;1',
#  'demo/preSelected/Njets;1',
#  'demo/preSelected/nLooseBTagJets;1',
#  'demo/preSelected/nMedBTagJets;1',
#  'demo/preSelected/nTightBTagjets;1',
#  'demo/preSelected/MinCaloJetDr;1',
#  'demo/preSelected/CaloJetPt;1',
#  'demo/preSelected/CaloJetPt_CaloConeEnergy;1',
#  'demo/preSelected/CaloJetEcalE;1',
#  'demo/preSelected/CaloJetHcalE;1',
#  'demo/preSelected/CaloJetTotalE;1',
#  'demo/preSelected/CaloConeEnergy;1',
#  'demo/preSelected/hcalIso0p3;1',
#  'demo/preSelected/hcalIso0p4;1',
#  'demo/preSelected/CaloConeHits;1',
#  'demo/preSelected/NHECellsFound;1',
#  'demo/preSelected/NeighborHECellsFound;1',
#  'demo/preSelected/HEEStandDEOverE;1',
#  'demo/preSelected/CSCdEtadPhi;1',
#  'demo/preSelected/CSCdEtadPhiPosQ;1',
#  'demo/preSelected/CSCdEtadPhiNegQ;1',
#  'demo/preSelected/CSCdPhi;1',
#  'demo/preSelected/CSCdPhiPosQ;1',
#  'demo/preSelected/CSCdPhiNegQ;1',
#  'demo/preSelected/standalonedPhi_hcalE;1',
#  'demo/preSelected/standalonedPhi_hcalE_lowStaDEoverE;1',
#  'demo/preSelected/StandalonedPhi;1',
#  'demo/preSelected/StandalonedPhiPosQ;1',
#  'demo/preSelected/StandalonedPhiPosQstaDEoverE;1',
#  'demo/preSelected/StandalonedPhiNegQ;1',
#  'demo/preSelected/StandalonedPhiNegQstaDEoverE;1',
#  'demo/preSelected/StandalonedEtadPhi;1',
#  'demo/preSelected/StandalonedEtadPhiPosQ;1',
#  'demo/preSelected/StandalonedEtadPhiNegQ;1',
#  'demo/preSelected/BigEtaCellCenterDistance;1',
#  'demo/preSelected/SmallEtaCellCenterDistance;1',
#  'demo/preSelected/CSCMinImpact;1',
#  'demo/preSelected/PairedVtxReducedChiSq;1',
#  'demo/preSelected/TrackIsolation;1',
#  'demo/preSelected/TrackQuality;1',
#  'demo/preSelected/TrackReducedChi;1',
#  'demo/preSelected/HcalPlusEcalE;1',
#  'demo/preSelected/ProbeTrackdxy;1',
#  'demo/preSelected/ProbeTrackdsz;1',
#  'demo/preSelected/ProbeTrackDCA;1',
#  'demo/preSelected/ProbeTrackLongDCA;1',
#  'demo/preSelected/ProbeTrackDCAphi;1',
#  'demo/preSelected/nElectrons;1',
#  'demo/preSelected/nExtraElectrons;1',
#  'demo/preSelected/nExtraMuons;1',
#  'demo/preSelected/standaloneChi2;1',
#  'demo/preSelected/standaloneNHits;1',
#  'demo/preSelected/standaloneTDCA;1',
#  'demo/preSelected/standaloneLongDCA;1',
#  'demo/preSelected/standalonechidEoverE;1',
#  'demo/preSelected/GenStandaloneMuondEoverE;1',
#  'demo/preSelected/DisGenStandaloneMuondEoverE;1',
#  'demo/preSelected/PileupWeights;1',
#  'demo/preSelected/NPUMean;1',
#  'demo/preSelected/energyBinSF;1',
#  'demo/preSelected/energyBin;1',
#  'demo/preSelected/totalMET;1',
#  'demo/preSelected/muMetMT;1',
#  'demo/preSelected/muAndProbeMetMT;1',
#  'demo/preSelected/depthsFound;1',
#  'demo/failSig;1',
#  'demo/failSig/genEventCount;1',
#  'demo/failSig/genEventCount_EnBin;1',
#  'demo/failSig/sigVariables;1',
#  'demo/failSig/eventCount;1',
#  'demo/failSig/eventCount_PUup;1',
#  'demo/failSig/eventCount_PUdown;1',
#  'demo/failSig/eventCount_IDup;1',
#  'demo/failSig/eventCount_IDdown;1',
#  'demo/failSig/eventCount_ISOup;1',
#  'demo/failSig/eventCount_ISOdown;1',
#  'demo/failSig/eventCount_Trigup;1',
#  'demo/failSig/eventCount_Trigdown;1',
#  'demo/failSig/eventCount_EnBin;1',
#  'demo/failSig/dbremWeight;1',
#  'demo/failSig/MuRocWeight;1',
#  'demo/failSig/IDSF;1',
#  'demo/failSig/IDSFup;1',
#  'demo/failSig/IDSFdown;1',
#  'demo/failSig/ISOSF;1',
#  'demo/failSig/ISOSFup;1',
#  'demo/failSig/ISOSFdown;1',
#  'demo/failSig/TrigSF;1',
#  'demo/failSig/TrigSFup;1',
#  'demo/failSig/TrigSFdown;1',
#  'demo/failSig/cutProgress;1',
#  'demo/failSig/signalCategory;1',
#  'demo/failSig/DiMuonInvariantMass;1',
#  'demo/failSig/TaggingMuonEta;1',
#  'demo/failSig/TaggingMuonPt;1',
#  'demo/failSig/NumberOfSelectedMuons;1',
#  'demo/failSig/NumberOfPairedProbes;1',
#  'demo/failSig/NeighborHCALHits;1',
#  'demo/failSig/NeighborHCALEnergy;1',
#  'demo/failSig/NeighborHEHitsByDepth;1',
#  'demo/failSig/ConeHits;1',
#  'demo/failSig/ConeEnergy;1',
#  'demo/failSig/ConeEnergy_PUup;1',
#  'demo/failSig/ConeEnergy_PUdown;1',
#  'demo/failSig/ConeEnergy_IDup;1',
#  'demo/failSig/ConeEnergy_IDdown;1',
#  'demo/failSig/ConeEnergy_ISOup;1',
#  'demo/failSig/ConeEnergy_ISOdown;1',
#  'demo/failSig/ConeEnergy_Trigup;1',
#  'demo/failSig/ConeEnergy_Trigdown;1',
#  'demo/failSig/ConeEnergy_EnBin;1',
#  'demo/failSig/NMatchNHitConeEnergy;1',
#  'demo/failSig/NMatchNHitLocation;1',
#  'demo/failSig/ProbeTrackPt;1',
#  'demo/failSig/ProbeTrackP;1',
#  'demo/failSig/ProbeTrackEta;1',
#  'demo/failSig/ProbeTrackPtEta;1',
#  'demo/failSig/ProbeTrackEtaPhi;1',
#  'demo/failSig/DarkBremLocation;1',
#  'demo/failSig/DeflectingAngle;1',
#  'demo/failSig/MuInitialE;1',
#  'demo/failSig/MuInitialE_noWeight;1',
#  'demo/failSig/MuInitialEt;1',
#  'demo/failSig/MuFinalE;1',
#  'demo/failSig/DarkBremScalingDistance;1',
#  'demo/failSig/ProbeEcalIsolation;1',
#  'demo/failSig/ProbeEcalIsolation0p2;1',
#  'demo/failSig/ProbeEcalIsolation0p1;1',
#  'demo/failSig/ProbeEcalIsolation0p05;1',
#  'demo/failSig/MotherTrackdE;1',
#  'demo/failSig/MotherTrackdR;1',
#  'demo/failSig/FailLocation;1',
#  'demo/failSig/FractionalELost;1',
#  'demo/failSig/HitsOverThresh;1',
#  'demo/failSig/BremDepth;1',
#  'demo/failSig/dRtoNearestCSC;1',
#  'demo/failSig/dRtoNearestCSC_Station0;1',
#  'demo/failSig/dRtoNearestDT_Station0;1',
#  'demo/failSig/dRtoNearestCSC_Station0missing;1',
#  'demo/failSig/dRtoNearestCSC_Station0good;1',
#  'demo/failSig/dRtoNearestCSC_Station0goodonly;1',
#  'demo/failSig/dRtoNearestCSC_Station1;1',
#  'demo/failSig/dRtoNearestDT_Station1;1',
#  'demo/failSig/dRtoNearestCSC_Station1missing;1',
#  'demo/failSig/dRtoNearestCSC_Station1good;1',
#  'demo/failSig/dRtoNearestCSC_Station1goodonly;1',
#  'demo/failSig/dRtoNearestCSC_Station2;1',
#  'demo/failSig/dRtoNearestDT_Station2;1',
#  'demo/failSig/dRtoNearestCSC_Station2missing;1',
#  'demo/failSig/dRtoNearestCSC_Station2good;1',
#  'demo/failSig/dRtoNearestCSC_Station2goodonly;1',
#  'demo/failSig/dRtoNearestCSC_Station3;1',
#  'demo/failSig/dRtoNearestDT_Station3;1',
#  'demo/failSig/dRtoNearestCSC_Station3missing;1',
#  'demo/failSig/dRtoNearestCSC_Station3good;1',
#  'demo/failSig/dRtoNearestCSC_Station3goodonly;1',
#  'demo/failSig/dRtoNearestSimCSC;1',
#  'demo/failSig/minSimCSCEloss;1',
#  'demo/failSig/nSimCSCHits;1',
#  'demo/failSig/nRecoCSCHits;1',
#  'demo/failSig/dRtoNearestCSCRecHit;1',
#  'demo/failSig/MuonMotherdE;1',
#  'demo/failSig/MuonMotherdR;1',
#  'demo/failSig/minGenMuDr;1',
#  'demo/failSig/minGenMuDE;1',
#  'demo/failSig/CSCChiSquared;1',
#  'demo/failSig/CSCDeflection;1',
#  'demo/failSig/StandaloneMuonE;1',
#  'demo/failSig/GlobaldMuonE;1',
#  'demo/failSig/StandaloneMuondEoverE;1',
#  'demo/failSig/StandaloneMuondEoverE_PUup;1',
#  'demo/failSig/StandaloneMuondEoverE_PUdown;1',
#  'demo/failSig/StandaloneMuondEoverE_IDup;1',
#  'demo/failSig/StandaloneMuondEoverE_IDdown;1',
#  'demo/failSig/StandaloneMuondEoverE_ISOup;1',
#  'demo/failSig/StandaloneMuondEoverE_ISOdown;1',
#  'demo/failSig/StandaloneMuondEoverE_Trigup;1',
#  'demo/failSig/StandaloneMuondEoverE_Trigdown;1',
#  'demo/failSig/StandaloneMuondEoverE_EnBin;1',
#  'demo/failSig/MatchedLocation;1',
#  'demo/failSig/AllClosestApproach;1',
#  'demo/failSig/EventWeights;1',
#  'demo/failSig/Dark Brem R;1',
#  'demo/failSig/HEHitsByDepth;1',
#  'demo/failSig/DrtoNearestStandalone;1',
#  'demo/failSig/ProbePFJetDr;1',
#  'demo/failSig/ProbePFJetE;1',
#  'demo/failSig/ProbePFJetMaxE;1',
#  'demo/failSig/Njets;1',
#  'demo/failSig/nLooseBTagJets;1',
#  'demo/failSig/nMedBTagJets;1',
#  'demo/failSig/nTightBTagjets;1',
#  'demo/failSig/MinCaloJetDr;1',
#  'demo/failSig/CaloJetPt;1',
#  'demo/failSig/CaloJetPt_CaloConeEnergy;1',
#  'demo/failSig/CaloJetEcalE;1',
#  'demo/failSig/CaloJetHcalE;1',
#  'demo/failSig/CaloJetTotalE;1',
#  'demo/failSig/CaloConeEnergy;1',
#  'demo/failSig/hcalIso0p3;1',
#  'demo/failSig/hcalIso0p4;1',
#  'demo/failSig/CaloConeHits;1',
#  'demo/failSig/NHECellsFound;1',
#  'demo/failSig/NeighborHECellsFound;1',
#  'demo/failSig/HEEStandDEOverE;1',
#  'demo/failSig/CSCdEtadPhi;1',
#  'demo/failSig/CSCdEtadPhiPosQ;1',
#  'demo/failSig/CSCdEtadPhiNegQ;1',
#  'demo/failSig/CSCdPhi;1',
#  'demo/failSig/CSCdPhiPosQ;1',
#  'demo/failSig/CSCdPhiNegQ;1',
#  'demo/failSig/standalonedPhi_hcalE;1',
#  'demo/failSig/standalonedPhi_hcalE_lowStaDEoverE;1',
#  'demo/failSig/StandalonedPhi;1',
#  'demo/failSig/StandalonedPhiPosQ;1',
#  'demo/failSig/StandalonedPhiPosQstaDEoverE;1',
#  'demo/failSig/StandalonedPhiNegQ;1',
#  'demo/failSig/StandalonedPhiNegQstaDEoverE;1',
#  'demo/failSig/StandalonedEtadPhi;1',
#  'demo/failSig/StandalonedEtadPhiPosQ;1',
#  'demo/failSig/StandalonedEtadPhiNegQ;1',
#  'demo/failSig/BigEtaCellCenterDistance;1',
#  'demo/failSig/SmallEtaCellCenterDistance;1',
#  'demo/failSig/CSCMinImpact;1',
#  'demo/failSig/PairedVtxReducedChiSq;1',
#  'demo/failSig/TrackIsolation;1',
#  'demo/failSig/TrackQuality;1',
#  'demo/failSig/TrackReducedChi;1',
#  'demo/failSig/HcalPlusEcalE;1',
#  'demo/failSig/ProbeTrackdxy;1',
#  'demo/failSig/ProbeTrackdsz;1',
#  'demo/failSig/ProbeTrackDCA;1',
#  'demo/failSig/ProbeTrackLongDCA;1',
#  'demo/failSig/ProbeTrackDCAphi;1',
#  'demo/failSig/nElectrons;1',
#  'demo/failSig/nExtraElectrons;1',
#  'demo/failSig/nExtraMuons;1',
#  'demo/failSig/standaloneChi2;1',
#  'demo/failSig/standaloneNHits;1',
#  'demo/failSig/standaloneTDCA;1',
#  'demo/failSig/standaloneLongDCA;1',
#  'demo/failSig/standalonechidEoverE;1',
#  'demo/failSig/GenStandaloneMuondEoverE;1',
#  'demo/failSig/DisGenStandaloneMuondEoverE;1',
#  'demo/failSig/PileupWeights;1',
#  'demo/failSig/NPUMean;1',
#  'demo/failSig/energyBinSF;1',
#  'demo/failSig/energyBin;1',
#  'demo/failSig/totalMET;1',
#  'demo/failSig/muMetMT;1',
#  'demo/failSig/muAndProbeMetMT;1',
#  'demo/failSig/depthsFound;1',
#  'demo/lowHits;1',
#  'demo/lowHits/genEventCount;1',
#  'demo/lowHits/genEventCount_EnBin;1',
#  'demo/lowHits/sigVariables;1',
#  'demo/lowHits/eventCount;1',
#  'demo/lowHits/eventCount_PUup;1',
#  'demo/lowHits/eventCount_PUdown;1',
#  'demo/lowHits/eventCount_IDup;1',
#  'demo/lowHits/eventCount_IDdown;1',
#  'demo/lowHits/eventCount_ISOup;1',
#  'demo/lowHits/eventCount_ISOdown;1',
#  'demo/lowHits/eventCount_Trigup;1',
#  'demo/lowHits/eventCount_Trigdown;1',
#  'demo/lowHits/eventCount_EnBin;1',
#  'demo/lowHits/dbremWeight;1',
#  'demo/lowHits/MuRocWeight;1',
#  'demo/lowHits/IDSF;1',
#  'demo/lowHits/IDSFup;1',
#  'demo/lowHits/IDSFdown;1',
#  'demo/lowHits/ISOSF;1',
#  'demo/lowHits/ISOSFup;1',
#  'demo/lowHits/ISOSFdown;1',
#  'demo/lowHits/TrigSF;1',
#  'demo/lowHits/TrigSFup;1',
#  'demo/lowHits/TrigSFdown;1',
#  'demo/lowHits/cutProgress;1',
#  'demo/lowHits/signalCategory;1',
#  'demo/lowHits/DiMuonInvariantMass;1',
#  'demo/lowHits/TaggingMuonEta;1',
#  'demo/lowHits/TaggingMuonPt;1',
#  'demo/lowHits/NumberOfSelectedMuons;1',
#  'demo/lowHits/NumberOfPairedProbes;1',
#  'demo/lowHits/NeighborHCALHits;1',
#  'demo/lowHits/NeighborHCALEnergy;1',
#  'demo/lowHits/NeighborHEHitsByDepth;1',
#  'demo/lowHits/ConeHits;1',
#  'demo/lowHits/ConeEnergy;1',
#  'demo/lowHits/ConeEnergy_PUup;1',
#  'demo/lowHits/ConeEnergy_PUdown;1',
#  'demo/lowHits/ConeEnergy_IDup;1',
#  'demo/lowHits/ConeEnergy_IDdown;1',
#  'demo/lowHits/ConeEnergy_ISOup;1',
#  'demo/lowHits/ConeEnergy_ISOdown;1',
#  'demo/lowHits/ConeEnergy_Trigup;1',
#  'demo/lowHits/ConeEnergy_Trigdown;1',
#  'demo/lowHits/ConeEnergy_EnBin;1',
#  'demo/lowHits/NMatchNHitConeEnergy;1',
#  'demo/lowHits/NMatchNHitLocation;1',
#  'demo/lowHits/ProbeTrackPt;1',
#  'demo/lowHits/ProbeTrackP;1',
#  'demo/lowHits/ProbeTrackEta;1',
#  'demo/lowHits/ProbeTrackPtEta;1',
#  'demo/lowHits/ProbeTrackEtaPhi;1',
#  'demo/lowHits/DarkBremLocation;1',
#  'demo/lowHits/DeflectingAngle;1',
#  'demo/lowHits/MuInitialE;1',
#  'demo/lowHits/MuInitialE_noWeight;1',
#  'demo/lowHits/MuInitialEt;1',
#  'demo/lowHits/MuFinalE;1',
#  'demo/lowHits/DarkBremScalingDistance;1',
#  'demo/lowHits/ProbeEcalIsolation;1',
#  'demo/lowHits/ProbeEcalIsolation0p2;1',
#  'demo/lowHits/ProbeEcalIsolation0p1;1',
#  'demo/lowHits/ProbeEcalIsolation0p05;1',
#  ...]

# %%
sameSignEvents=sameSignFile['demo']['allEvents']['sigVariables']
sameSignEvents
# Out:
# <TTree 'sigVariables' (47 branches) at 0x026ac15b88d0>

# %%
sameSignEvents.keys()
# Out:
# ['pt',
#  'eta',
#  'phi',
#  'staDR',
#  'staPhi',
#  'staE',
#  'standaloneDEoverE',
#  'staChi',
#  'cscDR',
#  'probeCharge',
#  'ecalIso',
#  'cellEdgeDeta',
#  'cellEdgeDphi',
#  'PUupWeight',
#  'PUdownWeight',
#  'IDupWeight',
#  'IDdownWeight',
#  'ISOupWeight',
#  'ISOdownWeight',
#  'TrigUpWeight',
#  'TrigDownWeight',
#  'EnBinWeight',
#  'lumi',
#  'event',
#  'cscDRbyStation_0',
#  'dtDRbyStation_0',
#  'cscDRbyStation_1',
#  'dtDRbyStation_1',
#  'cscDRbyStation_2',
#  'dtDRbyStation_2',
#  'cscDRbyStation_3',
#  'dtDRbyStation_3',
#  'HEDepth_0',
#  'found_HEDepth_0',
#  'HEDepth_1',
#  'found_HEDepth_1',
#  'HEDepth_2',
#  'found_HEDepth_2',
#  'HEDepth_3',
#  'found_HEDepth_3',
#  'HEDepth_4',
#  'found_HEDepth_4',
#  'HEDepth_5',
#  'found_HEDepth_5',
#  'HEDepth_6',
#  'found_HEDepth_6',
#  'EventWeight']

# %%
branches = sameSignEvents.arrays()
branches['pt']
# Out:
# <Array [42.6, 33.6, 48.1, 45.6, ..., 38.1, 38.3, 49.5] type='132572 * float64'>

# %%
import math

Muon_eta = branches['eta']
Muon_phi = branches['phi']

plt.hist(Muon_eta, bins=50, range=(-2.5, 2.5))
plt.title('Muon $\eta$ distribution in HCAL endcap')
plt.xlabel('Muon $\eta$')
plt.ylabel('Number of muons')
plt.show()

plt.hist(Muon_phi, bins=50, range=(-math.pi, math.pi))
plt.title('Muon $\phi$ distribution in HCAL endcap')
plt.xlabel('Muon $\phi$')
plt.ylabel('Number of muons')
plt.show()

# %%
print(len(Muon_eta), len(Muon_phi))
# Out:
# 132572 132572

# %%
import numpy as np
muon_eta=[float(value) for value in Muon_eta]
muon_phi=[float(value) for value in Muon_phi]
plt.hist2d(muon_eta, muon_phi, bins=(100,100), cmap=plt.cm.jet)
plt.title('HE Hit Distribution')
plt.xlabel('Muon $\eta$')
plt.ylabel('Muon $\phi$')
plt.colorbar(fraction=0.035, pad=0.04)
plt.show()

# %%
print(type(Muon_eta))
# Out:
# <class 'awkward.highlevel.Array'>

# %%
for i in range (4):
    min_DT_R = branches['dtDRbyStation_'+str(i)]

    plt.hist(min_DT_R, bins=100, range=(0, 3), density=True)
    plt.title('Distance to Station '+str(i)+' (Far)')
    plt.xlabel('$\Delta R$ to Station '+str(i))
    plt.ylabel('Event Fraction (Normalized)')
    plt.yscale('log')
    plt.show()

for i in range (4):
    min_DT_R = branches['dtDRbyStation_'+str(i)]

    plt.hist(min_DT_R, bins=100, range=(0, 0.35), density=True)
    plt.title('Distance to Station '+str(i)+' (Zoomed)')
    plt.xlabel('$\Delta R$ to Station '+str(i))
    plt.ylabel('Event Fraction (Normalized)')
    plt.yscale('log')
    plt.xticks(np.arange(0, 0.35, step=0.02), rotation='vertical')
    plt.show()

# %%
proximity_mask0 = (abs(branches['dtDRbyStation_0']) <= 0.185) & (branches['dtDRbyStation_0'] >= 0.14)
proximity_mask1 = (abs(branches['dtDRbyStation_0']) <= 0.205) & (branches['dtDRbyStation_0'] >= 0.185)
proximity_mask2 = (abs(branches['dtDRbyStation_0']) <= 0.246) & (branches['dtDRbyStation_0'] >= 0.185)
proximity_mask = [proximity_mask0, proximity_mask1, proximity_mask2]
print(np.sum(proximity_mask0),np.sum(proximity_mask1),np.sum(proximity_mask2))
# Out:
# 2405 595 2073

# %%
for i in range (4):
    min_DT_R = branches['dtDRbyStation_'+str(i)][proximity_mask0]

    plt.hist(min_DT_R, bins=100, range=(0, 0.35), density=True)
    plt.title('Distance to Station '+str(i)+' (Zoomed)')
    plt.xlabel('$\Delta R$ to Station '+str(i))
    plt.ylabel('Event Fraction (Normalized)')
    plt.yscale('log')
    plt.xticks(np.arange(0, 0.35, step=0.02), rotation='vertical')
    plt.show()

#No correlation

# %%
Muon_eta[proximity_mask0]
# Out:
# <Array [-1.17, 1.19, 0.402, ..., 0.847, -0.156, 1.21] type='2405 * float64'>

# %%
EventWeight = branches['EventWeight']
Muon_Eta = []
Muon_Phi = []
Event_Weight = []

for i in range (3):
    Muon_Eta.append([float(value) for value in Muon_eta[proximity_mask[i]]])
    Muon_Phi.append([float(value) for value in Muon_phi[proximity_mask[i]]])
    Event_Weight.append([float(value) for value in EventWeight[proximity_mask[i]]])
    plt.hist2d(Muon_Eta[i], Muon_Phi[i], bins=(100,100), range=[[-2.5, 2.5],[-math.pi, math.pi]], weights=Event_Weight[i], cmap=plt.cm.jet)
    plt.title('Weighted DT Hit Distribution with S0 secondary peak '+str(i)+' Proximity Mask')
    plt.xlabel('Muon $\eta$')
    plt.ylabel('Muon $\phi$')
    plt.colorbar(fraction=0.037, pad=0.04)
    plt.show()

# %%
Muon_EtaN = []
Muon_PhiN = []
Event_WeightN = []

for i in range (3):
    Muon_EtaN.append([float(value) for value in Muon_eta[~proximity_mask[i]]])
    Muon_PhiN.append([float(value) for value in Muon_phi[~proximity_mask[i]]])
    Event_WeightN.append([float(value) for value in EventWeight[~proximity_mask[i]]])
    plt.hist2d(Muon_EtaN[i], Muon_PhiN[i], bins=(100,100), range=[[-2.5, 2.5],[-math.pi, math.pi]], weights=Event_WeightN[i], cmap=plt.cm.jet)
    plt.title('Weighted DT Hit Distribution with Inverse S0 secondary peak '+str(i)+'  Proximity Mask')
    plt.xlabel('Muon $\eta$')
    plt.ylabel('Muon $\phi$')
    plt.colorbar(fraction=0.037, pad=0.04)
    plt.show()

# %%
import numpy

HT = numpy.histogram2d(Muon_eta, Muon_phi, bins=(100,100), range=[[-2.5, 2.5],[-math.pi, math.pi]], density=None, weights=EventWeight)
H = []
DT = []

for i in range (3):
    H.append(numpy.histogram2d(Muon_Eta[i], Muon_Phi[i], bins=(100,100), range=[[-2.5, 2.5],[-math.pi, math.pi]], density=None, weights=Event_Weight[i]))
    DT.append(numpy.divide(H[i][0],HT[0]))
    #bad_mask = DT[i] > 2
    #print(DT[i][bad_mask])
    #bad_indices = np.where(H[i][0] > HT[0]) 
    #print("Indices where H[{}][0] > HT[0]: {}".format(i, bad_indices))
    xedges, yedges = H[i][2], H[i][1]
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(131, title='Station 0 secondary peak '+str(i)+' DT hits (Data)')
    plt.imshow(DT[i], interpolation='nearest', origin='lower',
        extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
    plt.xlabel('Muon $\phi$')
    plt.ylabel('Muon $\eta$')
    plt.colorbar(fraction=0.035, pad=0.04)
    plt.show()
# Out:
# C:\Users\scien\AppData\Local\Programs\Python\Python311\Lib\site-packages\awkward\_backends\backend.py:47: RuntimeWarning: invalid value encountered in divide
#   return getattr(ufunc, method)(*args, **kwargs)

# %%
 neg_mask = []

for i in range (3):
    neg_mask.append(branches['dtDRbyStation_'+str(i)] == -1)
    plt.hist(Muon_eta[neg_mask[i]], bins=100, range=(-3, 3), density=None)
    plt.show()
